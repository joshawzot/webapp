# %%
# New Jupyter notebook
# Import common libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys

# Add core processing functions
import core_post_processing_functions as cf

# Your code here

# %%
rwb_pull = cf.rwb_fetch_data(regex='FF02', regex_col='DIE_ID')
# Out:
# Looking at table rwb_db_2
# Fetching FF02 regular expression filter on RWB column DIE_ID
# No data pulled from rwb_db_2
# Looking at table rwb_db_3
# Fetching FF02 regular expression filter on RWB column DIE_ID
# Data pulled from rwb_db_3
# Pull successful
